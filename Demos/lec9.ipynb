# %%
import seaborn as sns
import pandas as pd

# %%
movies = pd.read_csv('top_movies_2017.csv')
movies
# Out:
#                                   Title           Studio      Gross  \
# 0                    Gone with the Wind              MGM  198676459
# 1                             Star Wars              Fox  460998007
# 2                    The Sound of Music              Fox  158671368
# 3           E.T.: The Extra-Terrestrial        Universal  435110554
# 4                               Titanic        Paramount  658672302
# ..                                  ...              ...        ...
# 195                              9 to 5              Fox  103290500
# 196  Batman v Superman: Dawn of Justice  Warner Brothers  330360194
# 197                            The Firm        Paramount  158348367
# 198                       Suicide Squad  Warner Brothers  325100054
# 199             Who Framed Roger Rabbit      Buena Vista  156452370
#
#      Gross (Adjusted)  Year
# 0          1796176700  1939
# 1          1583483200  1977
# 2          1266072700  1965
# 3          1261085000  1982
# 4          1204368000  1997
# ..                ...   ...
# 195         341357800  1980
# 196         340137000  2016
# 197         340028200  1993
# 198         339411900  2016
# 199         338409100  1988
#
# [200 rows x 5 columns]

# %%
movies['Age'] = 2025 - movies['Year']
movies
# Out:
#                                   Title           Studio      Gross  \
# 0                    Gone with the Wind              MGM  198676459
# 1                             Star Wars              Fox  460998007
# 2                    The Sound of Music              Fox  158671368
# 3           E.T.: The Extra-Terrestrial        Universal  435110554
# 4                               Titanic        Paramount  658672302
# ..                                  ...              ...        ...
# 195                              9 to 5              Fox  103290500
# 196  Batman v Superman: Dawn of Justice  Warner Brothers  330360194
# 197                            The Firm        Paramount  158348367
# 198                       Suicide Squad  Warner Brothers  325100054
# 199             Who Framed Roger Rabbit      Buena Vista  156452370
#
#      Gross (Adjusted)  Year  Age
# 0          1796176700  1939   86
# 1          1583483200  1977   48
# 2          1266072700  1965   60
# 3          1261085000  1982   43
# 4          1204368000  1997   28
# ..                ...   ...  ...
# 195         341357800  1980   45
# 196         340137000  2016    9
# 197         340028200  1993   32
# 198         339411900  2016    9
# 199         338409100  1988   37
#
# [200 rows x 6 columns]

# %% [markdown]
# # Bar plot
#
# ## If you already have the numerical attribute as a column

# %%
sns.barplot(data=movies, 
            x='Title', 
            y='Age')

# what's wrong with this??
# Out:
# <Axes: xlabel='Title', ylabel='Age'>

# %%
ten_movies = movies.head(10)

sns.barplot(data=ten_movies, 
            y='Title', 
            x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Title'>

# %%
# more thought into picking which 10 movies to show

ten_oldest_movies = movies.sort_values('Age', ascending=False).head(10)

sns.barplot(data=ten_oldest_movies, 
            y='Title', 
            x='Age',
           color='tab:blue') # you can do this if you don't like rainbows 

# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors
# Out:
# <Axes: xlabel='Age', ylabel='Title'>

# %% [markdown]
# ## Age of top 10 grossing movies

# %%
movies.sort_values('Gross').head(10)
# Out:
#                                    Title           Studio     Gross  \
# 123  The Four Horsemen of the Apocalypse            Metro   9183673
# 111                        Sergeant York  Warner Brothers  16361885
# 99                       Duel in the Sun            Selz.  20408163
# 52               The Bells of St. Mary's              RKO  21333333
# 135                     The Caine Mutiny         Columbia  21750000
# 80           The Best Years of Our Lives              RKO  23650000
# 102                         House of Wax  Warner Brothers  23750000
# 85          The Bridge on the River Kwai         Columbia  27200000
# 152                               Psycho        Universal  32000000
# 59         The Greatest Showman on Earth        Paramount  36000000
#
#      Gross (Adjusted)  Year  Age
# 123         408214300  1921  104
# 111         427815200  1941   84
# 99          453571400  1946   79
# 52          557803900  1945   80
# 135         394607100  1954   71
# 80          488950000  1946   79
# 102         449228700  1953   72
# 85          483616000  1957   68
# 152         379306800  1960   65
# 59          533400000  1952   73

# %%
highest_grossing_movies = movies.sort_values('Gross',ascending=False)
highest_grossing_movies.head(10)
# Out:
#                                         Title           Studio      Gross  \
# 10               Star Wars: The Force Awakens      Buena Vista  936662225
# 14                                     Avatar              Fox  760507625
# 4                                     Titanic        Paramount  658672302
# 23                             Jurassic World        Universal  652270625
# 28                      Marvel's The Avengers      Buena Vista  623357910
# 30                            The Dark Knight  Warner Brothers  534858444
# 56               Rogue One: A Star Wars Story      Buena Vista  532177324
# 71                Beauty and the Beast (2017)      Buena Vista  504014165
# 72                               Finding Dory      Buena Vista  486295561
# 17  Star Wars: Episode I - The Phantom Menace              Fox  474544677
#
#     Gross (Adjusted)  Year  Age
# 10         961143200  2015   10
# 14         865082100  2009   16
# 4         1204368000  1997   28
# 23         702747400  2015   10
# 28         683474000  2012   13
# 30         661980500  2008   17
# 56         537326000  2016    9
# 71         504014165  2017    8
# 72         499245400  2016    9
# 17         802874300  1999   26

# %%
sns.barplot(data=highest_grossing_movies.head(10), 
            x='Age', 
            y='Title')
# Out:
# <Axes: xlabel='Age', ylabel='Title'>

# %% [markdown]
# ## Categorical distribution
#
# Barplot of counts (that you haven't counted yet) -> just use countplot from the start

# %%
sns.countplot(data=movies, 
              y='Studio')
# Out:
# <Axes: xlabel='count', ylabel='Studio'>

# %%
movies.Studio.value_counts()
# Out:
# Studio
# Buena Vista             35
# Warner Brothers         29
# Paramount               25
# Fox                     24
# Universal               23
# Disney                  11
# Columbia                 9
# MGM                      7
# United Artists           6
# Newline                  5
# Paramount/Dreamworks     4
# Sony                     4
# RKO                      3
# Dreamworks               3
# Lionsgate                3
# Tristar                  2
# NM                       1
# AVCO                     1
# Selz.                    1
# Metro                    1
# Orion                    1
# IFC                      1
# Sum.                     1
# Name: count, dtype: int64

# %%
sns.countplot(data=movies, 
              y='Studio', 
              order=movies.Studio.value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Studio'>

# %%
sns.countplot(data=movies, 
              y='Studio', 
              order=movies.Studio.value_counts(ascending=True).index,
             color='tab:blue')
# Out:
# <Axes: xlabel='count', ylabel='Studio'>

# %% [markdown]
# # Numerical distribution
#
# Use histplot

# %%
sns.histplot(data=movies, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
movies['Age'].describe()
# Out:
# count    200.000000
# mean      37.290000
# std       21.310009
# min        8.000000
# 25%       20.750000
# 50%       33.500000
# 75%       52.000000
# max      104.000000
# Name: Age, dtype: float64

# %%
sns.histplot(data=movies, x='Age', bins = range(0,110,10)) # range goes up to but not including!
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=movies, x='Age', bins = range(0,111,10))
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
my_bins = [0, 5, 10, 15, 25, 40, 65, 104] # bins also go up to but not including!
sns.histplot(data=movies, x='Age', bins = my_bins)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=movies, x='Age',stat='percent',bins=my_bins)
# Out:
# <Axes: xlabel='Age', ylabel='Percent'>

# %%
sns.histplot(data=movies, x='Age',stat='density',bins=my_bins)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
incomes = pd.read_csv('2022_female_actors.csv')
incomes.head()
# Out:
#                  Name  Income (millions)
# 0  Scarlett Johansson               56.0
# 1       Sofia Vergara               43.0
# 2      Angelina Jolie               35.5
# 3   Reese Witherspoon               35.0
# 4           Gal Gadot               31.5

# %%
incomes.describe()
# Out:
#        Income (millions)
# count          20.000000
# mean           26.550000
# std            10.258373
# min            12.500000
# 25%            21.250000
# 50%            24.500000
# 75%            30.375000
# max            56.000000

# %%
sns.histplot( incomes, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( incomes, bins=range(0,61,6)) # very different than above!
# Out:
# <Axes: ylabel='Count'>

# %%
my_bins = [0, 25, 30, 60]
sns.histplot( incomes, bins=my_bins)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( incomes, bins=my_bins, stat='density')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # More examples

# %%
lec1_poll=pd.DataFrame(data=['It will look good on my resume',
                             "I heard the teacher's cat is cute",
                             'It will look good on my resume',
                             'I need some credits',
                             'To learn about Data Science',
                             'I need some credits',
                             'I heard the teacher is great',
                             "I heard the teacher's cat is cute",
                             "I heard the teacher's cat is cute",
                             'It will look good on my resume',
                             'To learn about Data Science'], columns=['Response'])
lec1_poll
# Out:
#                              Response
# 0      It will look good on my resume
# 1   I heard the teacher's cat is cute
# 2      It will look good on my resume
# 3                 I need some credits
# 4         To learn about Data Science
# 5                 I need some credits
# 6        I heard the teacher is great
# 7   I heard the teacher's cat is cute
# 8   I heard the teacher's cat is cute
# 9      It will look good on my resume
# 10        To learn about Data Science

# %%
sns.barplot(data=lec1_poll.value_counts('Response'),orient='h')
# Out:
# <Axes: xlabel='count', ylabel='Response'>

# %%
sns.barplot(data=lec1_poll.value_counts('Response',normalize=True),orient='h')
# Out:
# <Axes: xlabel='proportion', ylabel='Response'>
